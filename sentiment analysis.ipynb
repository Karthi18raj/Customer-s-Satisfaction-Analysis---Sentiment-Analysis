# %%
import pandas as pd
book_train = pd.read_csv("/Users/karthick/Desktop/Analysis/books/rdpd.csv")
cam_train = pd.read_csv("/Users/karthick/Desktop/Analysis/camera/camera.csv")
mob_train = pd.read_csv("/Users/karthick/Desktop/Analysis/Electronics_mobile/testdata.csv")
ent_train = pd.read_csv("/Users/karthick/Desktop/Analysis/entertainment/buds.csv")
house_train = pd.read_csv("/Users/karthick/Desktop/Analysis/household/dettol.csv")
watch_train = pd.read_csv("/Users/karthick/Desktop/Analysis/watches/titan.csv")

# %%
book_train.head()
cam_train.head()
mob_train.head()
ent_train.head()
house_train.head()
watch_train.head()
# Out:
#   web-scraper-order                              web-scraper-start-url  \
# 0  1590769664-15942  https://www.amazon.in/Titan-Youth-Analog-Women...
# 1  1590769535-15513  https://www.amazon.in/Titan-Youth-Analog-Women...
# 2  1590769595-15705  https://www.amazon.in/Titan-Youth-Analog-Women...
# 3  1590769535-15504  https://www.amazon.in/Titan-Youth-Analog-Women...
# 4  1590769648-15892  https://www.amazon.in/Titan-Youth-Analog-Women...
#
#              author                                     title  \
# 0  Arvind Upadhyaya                        Good looking watch
# 1             kajol  Watch is best but outer packaging worst.
# 2          Ruchi P.                               Three Stars
# 3   Amazon Customer                 Dont buy from this seller
# 4     PRADEEP KUMAR                                   Awesome
#
#                                     date  \
# 0      Reviewed in India on 30 July 2016
# 1    Reviewed in India on 2 October 2019
# ...

# %%
book_train = book_train.drop(["web-scraper-order", "web-scraper-start-url", "author","next","next-href"], axis=1)
cam_train = cam_train.drop(["web-scraper-order", "web-scraper-start-url", "author","next","next-href"], axis=1)
mob_train = mob_train.drop(["web-scraper-order", "web-scraper-start-url", "author","next","next-href"], axis=1)
ent_train = ent_train.drop(["web-scraper-order", "web-scraper-start-url", "author","next","next-href"], axis=1)
house_train = house_train.drop(["web-scraper-order", "web-scraper-start-url", "author","next","next-href"], axis=1)
watch_train = watch_train.drop(["web-scraper-order", "web-scraper-start-url", "author","next","next-href"], axis=1)

# %%
book_train['Reviews']= book_train["title"].astype(str) +" "+ book_train["content"]
cam_train['Reviews']= cam_train["title"].astype(str) +" "+ cam_train["content"]
mob_train['Reviews']= mob_train["title"].astype(str) +" "+ mob_train["content"]
ent_train['Reviews']= ent_train["title"].astype(str) +" "+ ent_train["content"]
house_train['Reviews']= house_train["title"].astype(str) +" "+ house_train["content"]
watch_train['Reviews']= watch_train["title"].astype(str) +" "+ watch_train["content"]

# %%
book_train["Category"] = str('books')
cam_train["Category"] = str('camera')
mob_train["Category"] = str('mobile')
ent_train["Category"] = str('entertainment')
house_train["Category"] = str('households')
watch_train["Category"] = str('watches')

# %%
book_train = book_train.drop(["title","content"],axis=1)
cam_train = cam_train.drop(["title","content"],axis=1)
mob_train = mob_train.drop(["title","content"],axis=1)
ent_train = ent_train.drop(["title","content"],axis=1)
house_train = house_train.drop(["title","content"],axis=1)
watch_train = watch_train.drop(["title","content"],axis=1)

# %%
watch_train.head()
# Out:
#                                     date              rating  \
# 0      Reviewed in India on 30 July 2016  5.0 out of 5 stars
# 1    Reviewed in India on 2 October 2019  5.0 out of 5 stars
# 2      Reviewed in India on 26 June 2017  3.0 out of 5 stars
# 3  Reviewed in India on 26 November 2018  1.0 out of 5 stars
# 4    Reviewed in India on 22 August 2019  4.0 out of 5 stars
#
#                                              Reviews Category
# 0  Good looking watch Its a great looking watch.....  watches
# 1  Watch is best but outer packaging worst. The p...  watches
# 2  Three Stars The watch looks beautiful...But th...  watches
# 3  Dont buy from this seller Very very bad packag...  watches
# 4                                       Awesome Nice  watches

# %%
frames = [book_train,cam_train,mob_train,ent_train,house_train,watch_train]
train = pd.concat(frames)
train.head()
# Out:
#                                   date              rating  \
# 0    Reviewed in India on 11 June 2016  5.0 out of 5 stars
# 1  Reviewed in India on 5 October 2017  5.0 out of 5 stars
# 2   Reviewed in India on 18 March 2017  4.0 out of 5 stars
# 3    Reviewed in India on 28 June 2019  5.0 out of 5 stars
# 4   Reviewed in India on 25 April 2015  5.0 out of 5 stars
#
#                                              Reviews Category
# 0                      Five Stars Life changing book    books
# 1  I purchased a series of Books to read and unde...    books
# 2  one of the best books if u are eally looking f...    books
# 3                      ..good read... ..good read...    books
# 4  Five Stars this is very good book every one sh...    books

# %%
train.shape
# Out:
# (18429, 4)

# %%
train['Rating'] = train['rating'].str.split(' ')
train.head()
# Out:
#                                   date              rating  \
# 0    Reviewed in India on 11 June 2016  5.0 out of 5 stars
# 1  Reviewed in India on 5 October 2017  5.0 out of 5 stars
# 2   Reviewed in India on 18 March 2017  4.0 out of 5 stars
# 3    Reviewed in India on 28 June 2019  5.0 out of 5 stars
# 4   Reviewed in India on 25 April 2015  5.0 out of 5 stars
#
#                                              Reviews Category  \
# 0                      Five Stars Life changing book    books
# 1  I purchased a series of Books to read and unde...    books
# 2  one of the best books if u are eally looking f...    books
# 3                      ..good read... ..good read...    books
# 4  Five Stars this is very good book every one sh...    books
#
#                      Rating
# 0  [5.0, out, of, 5, stars]
# 1  [5.0, out, of, 5, stars]
# 2  [4.0, out, of, 5, stars]
# 3  [5.0, out, of, 5, stars]
# 4  [5.0, out, of, 5, stars]

# %%
train["Rating_score"] = train["Rating"].str[0]
train.head()
# Out:
#                                   date              rating  \
# 0    Reviewed in India on 11 June 2016  5.0 out of 5 stars
# 1  Reviewed in India on 5 October 2017  5.0 out of 5 stars
# 2   Reviewed in India on 18 March 2017  4.0 out of 5 stars
# 3    Reviewed in India on 28 June 2019  5.0 out of 5 stars
# 4   Reviewed in India on 25 April 2015  5.0 out of 5 stars
#
#                                              Reviews Category  \
# 0                      Five Stars Life changing book    books
# 1  I purchased a series of Books to read and unde...    books
# 2  one of the best books if u are eally looking f...    books
# 3                      ..good read... ..good read...    books
# 4  Five Stars this is very good book every one sh...    books
#
#                      Rating Rating_score
# 0  [5.0, out, of, 5, stars]          5.0
# 1  [5.0, out, of, 5, stars]          5.0
# 2  [4.0, out, of, 5, stars]          4.0
# 3  [5.0, out, of, 5, stars]          5.0
# ...

# %%
train = train.drop(["rating","Rating"],axis=1)
train.head()
# Out:
#                                   date  \
# 0    Reviewed in India on 11 June 2016
# 1  Reviewed in India on 5 October 2017
# 2   Reviewed in India on 18 March 2017
# 3    Reviewed in India on 28 June 2019
# 4   Reviewed in India on 25 April 2015
#
#                                              Reviews Category Rating_score
# 0                      Five Stars Life changing book    books          5.0
# 1  I purchased a series of Books to read and unde...    books          5.0
# 2  one of the best books if u are eally looking f...    books          4.0
# 3                      ..good read... ..good read...    books          5.0
# 4  Five Stars this is very good book every one sh...    books          5.0

# %%
train['date'] = train['date'].str.split(n=4)
train.head()
# Out:
#                                         date  \
# 0    [Reviewed, in, India, on, 11 June 2016]
# 1  [Reviewed, in, India, on, 5 October 2017]
# 2   [Reviewed, in, India, on, 18 March 2017]
# 3    [Reviewed, in, India, on, 28 June 2019]
# 4   [Reviewed, in, India, on, 25 April 2015]
#
#                                              Reviews Category Rating_score
# 0                      Five Stars Life changing book    books          5.0
# 1  I purchased a series of Books to read and unde...    books          5.0
# 2  one of the best books if u are eally looking f...    books          4.0
# 3                      ..good read... ..good read...    books          5.0
# 4  Five Stars this is very good book every one sh...    books          5.0

# %%
train["Date"] = train["date"].str[4]
train.head()
# Out:
#                                         date  \
# 0    [Reviewed, in, India, on, 11 June 2016]
# 1  [Reviewed, in, India, on, 5 October 2017]
# 2   [Reviewed, in, India, on, 18 March 2017]
# 3    [Reviewed, in, India, on, 28 June 2019]
# 4   [Reviewed, in, India, on, 25 April 2015]
#
#                                              Reviews Category Rating_score  \
# 0                      Five Stars Life changing book    books          5.0
# 1  I purchased a series of Books to read and unde...    books          5.0
# 2  one of the best books if u are eally looking f...    books          4.0
# 3                      ..good read... ..good read...    books          5.0
# 4  Five Stars this is very good book every one sh...    books          5.0
#
#              Date
# 0    11 June 2016
# 1  5 October 2017
# 2   18 March 2017
# 3    28 June 2019
# 4   25 April 2015

# %%
train = train.drop(["date"],axis=1)
train.head()
# Out:
#                                              Reviews Category Rating_score  \
# 0                      Five Stars Life changing book    books          5.0
# 1  I purchased a series of Books to read and unde...    books          5.0
# 2  one of the best books if u are eally looking f...    books          4.0
# 3                      ..good read... ..good read...    books          5.0
# 4  Five Stars this is very good book every one sh...    books          5.0
#
#              Date
# 0    11 June 2016
# 1  5 October 2017
# 2   18 March 2017
# 3    28 June 2019
# 4   25 April 2015

# %%
train.to_csv("/Users/karthick/Desktop/Analysis/train.csv", index=True, encoding='utf8')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
x=train['Rating_score'].value_counts()
x=x.sort_index()
plt.figure(figsize=(10,6))
ax= sns.barplot(x.index, x.values, alpha=0.8)
plt.title("Star Rating Distribution")
plt.ylabel('count')
plt.xlabel('Star Ratings')
rects = ax.patches
labels = x.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')
plt.show();

# %%
train["year"] = pd.to_datetime(train["Date"]).dt.year
train["month"] = pd.to_datetime(train["Date"]).dt.month
train.head()
# Out:
#                                              Reviews Category Rating_score  \
# 0                      Five Stars Life changing book    books          5.0
# 1  I purchased a series of Books to read and unde...    books          5.0
# 2  one of the best books if u are eally looking f...    books          4.0
# 3                      ..good read... ..good read...    books          5.0
# 4  Five Stars this is very good book every one sh...    books          5.0
#
#              Date    year  month
# 0    11 June 2016  2016.0    6.0
# 1  5 October 2017  2017.0   10.0
# 2   18 March 2017  2017.0    3.0
# 3    28 June 2019  2019.0    6.0
# 4   25 April 2015  2015.0    4.0

# %%
plt.figure(figsize=(10,6))
x=train['year'].value_counts()
x=x.sort_index()
plt.title("Reviews per year")
plt.ylabel('count')
plt.xlabel('Year')
ax= sns.barplot(x.index, x.values, alpha=0.8)
rects = ax.patches
labels = x.values
for rect, label in zip(rects, labels):
    height = rect.get_height()
    ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center', va='bottom')
plt.show();

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  
import nltk
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer, WordNetLemmatizer, PorterStemmer
from wordcloud import WordCloud, STOPWORDS
from textblob import TextBlob

# %%
train["Reviews"]= train["Reviews"].astype(str)
train.dtypes
# Out:
# Reviews          object
# Category         object
# Rating_score     object
# Date             object
# year            float64
# month           float64
# dtype: object

# %%
import nltk
nltk.download('stopwords')
stop = stopwords.words('english')
train['Reviews'] = train['Reviews'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
train.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\karthick\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                              Reviews Category Rating_score  \
# 0                      Five Stars Life changing book    books          5.0
# 1  I purchased series Books read understand ... I...    books          5.0
# 2  one best books u eally looking forward go ... ...    books          4.0
# 3                      ..good read... ..good read...    books          5.0
# 4                Five Stars good book every one read    books          5.0
#
#              Date    year  month
# 0    11 June 2016  2016.0    6.0
# 1  5 October 2017  2017.0   10.0
# 2   18 March 2017  2017.0    3.0
# 3    28 June 2019  2019.0    6.0
# 4   25 April 2015  2015.0    4.0

# %%
st = PorterStemmer()
train['Reviews'] = train['Reviews'].astype(str).apply(lambda x: " ".join([st.stem(word) for word in x.split()]))

# %%
train.head()
# Out:
#                                              Reviews Category Rating_score  \
# 0                          five star life chang book    books          5.0
# 1  I purchas seri book read understand ... I purc...    books          5.0
# 2  one best book u ealli look forward go ... one ...    books          4.0
# 3                      ..good read... ..good read...    books          5.0
# 4                 five star good book everi one read    books          5.0
#
#              Date    year  month
# 0    11 June 2016  2016.0    6.0
# 1  5 October 2017  2017.0   10.0
# 2   18 March 2017  2017.0    3.0
# 3    28 June 2019  2019.0    6.0
# 4   25 April 2015  2015.0    4.0

# %%
def senti(x):
    return TextBlob(x).sentiment.polarity 
train['pol'] = train['Reviews'].apply(senti)
train.head()
# Out:
#                                              Reviews Category Rating_score  \
# 0                          five star life chang book    books          5.0
# 1  I purchas seri book read understand ... I purc...    books          5.0
# 2  one best book u ealli look forward go ... one ...    books          4.0
# 3                      ..good read... ..good read...    books          5.0
# 4                 five star good book everi one read    books          5.0
#
#              Date    year  month     pol
# 0    11 June 2016  2016.0    6.0  0.0000
# 1  5 October 2017  2017.0   10.0  0.1875
# 2   18 March 2017  2017.0    3.0  1.0000
# 3    28 June 2019  2019.0    6.0  0.0000
# 4   25 April 2015  2015.0    4.0  0.7000

# %%
train.tail()
# Out:
#                                                Reviews Category Rating_score  \
# 739  it wortabl product everyon like wear it wortab...  watches          5.0
# 740                          five star veri good. eleg  watches          5.0
# 741                                          good nice  watches          4.0
# 742                                          best best  watches          5.0
# 743  insuffici product detail bill warranti provid ...  watches          5.0
#
#                  Date    year  month   pol
# 739   6 November 2019  2019.0   11.0  0.00
# 740    21 August 2015  2015.0    8.0  0.70
# 741  29 November 2018  2018.0   11.0  0.65
# 742  8 September 2019  2019.0    9.0  1.00
# 743     10 March 2019  2019.0    3.0  0.00

# %%
train["pol"].mean()
# Out:
# 0.3595756931433054

# %%
num_bins = 50
plt.figure(figsize=(10,6))
n, bins, patches = plt.hist(train.pol, num_bins, facecolor='blue', alpha=0.5)
plt.xlabel('Polarity')
plt.ylabel('Count')
plt.title('Histogram of polarity')
plt.show();

# %%
plt.figure(figsize=(10,6))
sns.boxenplot(x='Rating_score', y='pol', data=train)
plt.show();

# %%
import numpy as np
train['polarity'] = np.where(pd.to_numeric(train['pol']) > 0,1,0)
train['polarity'] = np.where(pd.to_numeric(train['pol']) < 0,-1,train["polarity"])
train.head(10)
# Out:
#                                              Reviews Category Rating_score  \
# 0                          five star life chang book    books          5.0
# 1  I purchas seri book read understand ... I purc...    books          5.0
# 2  one best book u ealli look forward go ... one ...    books          4.0
# 3                      ..good read... ..good read...    books          5.0
# 4                 five star good book everi one read    books          5.0
# 5  love it..an interest portray account A great b...    books          4.0
# 6                veri good product veri good product    books          5.0
# 7  An eye-open book If want realli accumul rich c...    books          5.0
# 8  A beginner' approach "saving" money In simplis...    books          5.0
# 9  take risk success good book must read anyon li...    books          5.0
#
#               Date    year  month       pol  polarity
# 0     11 June 2016  2016.0    6.0  0.000000         0
# ...

# %%
train.head(30)
# Out:
#                                               Reviews Category Rating_score  \
# 0                           five star life chang book    books          5.0
# 1   I purchas seri book read understand ... I purc...    books          5.0
# 2   one best book u ealli look forward go ... one ...    books          4.0
# 3                       ..good read... ..good read...    books          5.0
# 4                  five star good book everi one read    books          5.0
# 5   love it..an interest portray account A great b...    books          4.0
# 6                 veri good product veri good product    books          5.0
# 7   An eye-open book If want realli accumul rich c...    books          5.0
# 8   A beginner' approach "saving" money In simplis...    books          5.0
# 9   take risk success good book must read anyon li...    books          5.0
# 10  A financi guid everyon must read everi one wan...    books          4.0
# ...

# %%
train["Rating_score"]=pd.to_numeric(train["Rating_score"])

# %%
train["Date"]=pd.to_datetime(train["Date"])
train.dtypes
# Out:
# Reviews                 object
# Category                object
# Rating_score           float64
# Date            datetime64[ns]
# year                   float64
# month                  float64
# pol                    float64
# polarity                 int32
# dtype: object

# %%
train.describe()
# Out:
#        Rating_score          year         month           pol      polarity
# count  18423.000000  18423.000000  18423.000000  18429.000000  18429.000000
# mean       4.002280   2018.984150      6.365033      0.359576      0.650442
# std        1.407286      1.171148      4.066221      0.375061      0.662745
# min        1.000000   2013.000000      1.000000     -1.000000     -1.000000
# 25%        3.000000   2019.000000      3.000000      0.024554      1.000000
# 50%        5.000000   2019.000000      6.000000      0.412500      1.000000
# 75%        5.000000   2020.000000     11.000000      0.666667      1.000000
# max        5.000000   2020.000000     12.000000      1.000000      1.000000

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 18429 entries, 0 to 743
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Reviews       18429 non-null  object
#  1   Category      18429 non-null  object
#  2   Rating_score  18423 non-null  float64
#  3   Date          18423 non-null  datetime64[ns]
#  4   year          18423 non-null  float64
#  5   month         18423 non-null  float64
#  6   pol           18429 non-null  float64
#  7   polarity      18429 non-null  int32
# dtypes: datetime64[ns](1), float64(4), int32(1), object(2)
# memory usage: 1.8+ MB

# %%
train.to_csv("/Users/Karthick/Desktop/Analysis/train_labeled.csv", index=True, encoding='utf8')

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(train['Reviews'],train['polarity'],random_state=0)

# %%
print('X_train first entry:\n\n', X_train.iloc[0])
print('\n\nX_train shape: ', X_train.shape)
# Out:
# X_train first entry:
#
#  poor qualiti phone haven't seen phone high spec low quality. camera useless. though hype sale, lac quality. color product look artificial. zoom anoth desaster. screen look good multitask smoother. but realli disappoint redmi hardware. I feel anoth phone compet market rais specif phone qualiti realli poor.
#
#
# X_train shape:  (13821,)

# %%
from sklearn.feature_extraction.text import CountVectorizer
vect = CountVectorizer().fit(X_train)

# %%
vect.get_feature_names()[::2000]
# Out:
# ['00', 'buildinga', 'famous', 'loophol', 'ratio', 'ts']

# %%
len(vect.get_feature_names())
# Out:
# 10920

# %%
X_train_vectorized = vect.transform(X_train)

X_train_vectorized
# Out:
# <13821x10920 sparse matrix of type '<class 'numpy.int64'>'
# 	with 197995 stored elements in Compressed Sparse Row format>

# %%
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors = 10)
model.fit(X_train_vectorized, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
from sklearn.metrics import confusion_matrix
predictions = model.predict(vect.transform(X_test))
print('CM: ',confusion_matrix(y_test,predictions))
# Out:
# CM:  [[ 218  110  176]
#  [  14  403  169]
#  [  35  332 3151]]

# %%
from sklearn.metrics import plot_confusion_matrix
cnf_matrix = confusion_matrix(y_test,predictions,labels=[1, 0, -1])
np.set_printoptions(precision=2)
# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(model,vect.transform(X_test),y_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
# Accuracy = TP + TN / (TP + TN + FP + FN)
# Precision = TP / (TP + FP)
# Recall = TP / (TP + FN)  Also known as sensitivity, or True Positive Rate
# F1 = 2 * Precision * Recall / (Precision + Recall) 
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, predictions)))
print('Micro Precision: {:}'.format(precision_score(y_test, predictions,average='micro')))
print('Macro Precision: {:}'.format(precision_score(y_test, predictions,average='macro')))
print('Micro Recall: {:}'.format(recall_score(y_test, predictions,average='micro')))
print('Macro Recall: {:}'.format(recall_score(y_test, predictions,average='macro')))
print('Micro F1: {:}'.format(f1_score(y_test, predictions,average='micro')))
print('Macro F1: {:}'.format(f1_score(y_test, predictions,average='macro')))
print(classification_report(y_test, predictions))
# Out:
# Accuracy: 0.82
# Micro Precision: 0.8185763888888888
# Macro Precision: 0.731572755715275
# Micro Recall: 0.8185763888888888
# Macro Recall: 0.6719774521314917
# Micro F1: 0.8185763888888888
# Macro F1: 0.6757435253581496
#               precision    recall  f1-score   support
#
#           -1       0.82      0.43      0.57       504
#            0       0.48      0.69      0.56       586
#            1       0.90      0.90      0.90      3518
#
#     accuracy                           0.82      4608
#    macro avg       0.73      0.67      0.68      4608
# weighted avg       0.84      0.82      0.82      4608

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train_vectorized, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
from sklearn.metrics import confusion_matrix 
predictions = model.predict(vect.transform(X_test))

print('CM: ',confusion_matrix(y_test,predictions))
# Out:
# CM:  [[ 376   25  103]
#  [  20  524   42]
#  [  85   40 3393]]

# %%
from sklearn.metrics import plot_confusion_matrix
cnf_matrix = confusion_matrix(y_test,predictions,labels=[1, 0, -1])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(model,vect.transform(X_test),y_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
# Accuracy = TP + TN / (TP + TN + FP + FN)
# Precision = TP / (TP + FP)
# Recall = TP / (TP + FN)  Also known as sensitivity, or True Positive Rate
# F1 = 2 * Precision * Recall / (Precision + Recall) 
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, predictions)))
print('Micro Precision: {:}'.format(precision_score(y_test, predictions,average='micro')))
print('Macro Precision: {:}'.format(precision_score(y_test, predictions,average='macro')))
print('Micro Recall: {:}'.format(recall_score(y_test, predictions,average='micro')))
print('Macro Recall: {:}'.format(recall_score(y_test, predictions,average='macro')))
print('Micro F1: {:}'.format(f1_score(y_test, predictions,average='micro')))
print('Macro F1: {:}'.format(f1_score(y_test, predictions,average='macro')))
print(classification_report(y_test, predictions))
# Out:
# Accuracy: 0.93
# Micro Precision: 0.931640625
# Macro Precision: 0.8767882128816193
# Micro Recall: 0.931640625
# Macro Recall: 0.8682327154106613
# Micro F1: 0.931640625
# Macro F1: 0.8723671213814396
#               precision    recall  f1-score   support
#
#           -1       0.78      0.75      0.76       504
#            0       0.89      0.89      0.89       586
#            1       0.96      0.96      0.96      3518
#
#     accuracy                           0.93      4608
#    macro avg       0.88      0.87      0.87      4608
# weighted avg       0.93      0.93      0.93      4608

# %%
from sklearn import naive_bayes
model = naive_bayes.MultinomialNB()
model.fit(X_train_vectorized, y_train)

predictions = model.predict(vect.transform(X_test))

# %%
from sklearn.metrics import confusion_matrix 
predictions = model.predict(vect.transform(X_test))

print('CM: ',confusion_matrix(y_test,predictions))
# Out:
# CM:  [[ 309   15  180]
#  [  88  206  292]
#  [ 101   62 3355]]

# %%
from sklearn.metrics import plot_confusion_matrix
cnf_matrix = confusion_matrix(y_test,predictions,labels=[1, 0, -1])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(model,vect.transform(X_test),y_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
# Accuracy = TP + TN / (TP + TN + FP + FN)
# Precision = TP / (TP + FP)
# Recall = TP / (TP + FN)  Also known as sensitivity, or True Positive Rate
# F1 = 2 * Precision * Recall / (Precision + Recall) 
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, predictions)))
print('Micro Precision: {:}'.format(precision_score(y_test, predictions,average='micro')))
print('Macro Precision: {:}'.format(precision_score(y_test, predictions,average='macro')))
print('Micro Recall: {:}'.format(recall_score(y_test, predictions,average='micro')))
print('Macro Recall: {:}'.format(recall_score(y_test, predictions,average='macro')))
print('Micro F1: {:}'.format(f1_score(y_test, predictions,average='micro')))
print('Macro F1: {:}'.format(f1_score(y_test, predictions,average='macro')))
print(classification_report(y_test, predictions))
# Out:
# Accuracy: 0.84
# Micro Precision: 0.83984375
# Macro Precision: 0.7416876392398439
# Micro Recall: 0.83984375
# Macro Recall: 0.63943264348033
# Micro F1: 0.83984375
# Macro F1: 0.6681404225791199
#               precision    recall  f1-score   support
#
#           -1       0.62      0.61      0.62       504
#            0       0.73      0.35      0.47       586
#            1       0.88      0.95      0.91      3518
#
#     accuracy                           0.84      4608
#    macro avg       0.74      0.64      0.67      4608
# weighted avg       0.83      0.84      0.83      4608

# %%
# get the feature names as numpy array
feature_names = np.array(vect.get_feature_names())
# Sort the coefficients from the model
sorted_coef_index = model.coef_[0].argsort()
# Find the 10 smallest and 10 largest coefficients
# The 10 largest coefficients are being indexed using [:-11:-1]
# so the list returned is in order of largest to smallest
print('Smallest Coefs:\n{}\n'.format(feature_names[sorted_coef_index[:10]]))
print('Largest Coefs: \n{}'.format(feature_names[sorted_coef_index[:-11:-1]]))
print('Coefs:\n{}\n'.format(feature_names[sorted_coef_index]))
# Out:
# Smallest Coefs:
# ['00' 'mouth' 'mousuf' 'mousu' 'mous' 'mount' 'motorola' 'motor' 'moto'
#  'motives']
#
# Largest Coefs:
# ['product' 'bad' 'qualiti' 'phone' 'worst' 'poor' 'not' 'buy' 'camera'
#  'it']
# Coefs:
# ['00' 'mouth' 'mousuf' ... 'qualiti' 'bad' 'product']

# %%
neg_text = feature_names[sorted_coef_index[:100]]
pos_text = feature_names[sorted_coef_index[-100:-1]]

# %%
wordcloud = WordCloud(width = 1000, height = 500).generate(str(neg_text))
plt.figure(figsize=(20,10))
plt.figure()
plt.title('negative words')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(width = 1000, height = 500).generate(str(pos_text))
plt.figure(figsize=(20,10))
plt.figure()
plt.title('postive words')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Fit the TfidfVectorizer to the training data specifiying a minimum document frequency of 5
vect = TfidfVectorizer(min_df=5).fit(X_train)
len(vect.get_feature_names())
# Out:
# 2867

# %%
X_train_vectorized = vect.transform(X_train)
from sklearn import naive_bayes
model = naive_bayes.MultinomialNB()
model.fit(X_train_vectorized, y_train)

predictions = model.predict(vect.transform(X_test))

# %%
from sklearn.metrics import confusion_matrix 
predictions = model.predict(vect.transform(X_test))

print('CM: ',confusion_matrix(y_test,predictions))
# Out:
# CM:  [[ 143    5  356]
#  [  19   61  506]
#  [  22   12 3484]]

# %%
from sklearn.metrics import plot_confusion_matrix
cnf_matrix = confusion_matrix(y_test,predictions,labels=[1, 0, -1])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(model,vect.transform(X_test),y_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
# Accuracy = TP + TN / (TP + TN + FP + FN)
# Precision = TP / (TP + FP)
# Recall = TP / (TP + FN)  Also known as sensitivity, or True Positive Rate
# F1 = 2 * Precision * Recall / (Precision + Recall) 
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, predictions)))
print('Micro Precision: {:}'.format(precision_score(y_test, predictions,average='micro')))
print('Macro Precision: {:}'.format(precision_score(y_test, predictions,average='macro')))
print('Micro Recall: {:}'.format(recall_score(y_test, predictions,average='micro')))
print('Macro Recall: {:}'.format(recall_score(y_test, predictions,average='macro')))
print('Micro F1: {:}'.format(f1_score(y_test, predictions,average='micro')))
print('Macro F1: {:}'.format(f1_score(y_test, predictions,average='macro')))
print(classification_report(y_test, predictions))
# Out:
# Accuracy: 0.80
# Micro Precision: 0.8003472222222222
# Macro Precision: 0.7869606303023339
# Micro Recall: 0.8003472222222222
# Macro Recall: 0.45938704657371404
# Micro F1: 0.8003472222222222
# Macro F1: 0.49516522880183816
#               precision    recall  f1-score   support
#
#           -1       0.78      0.28      0.42       504
#            0       0.78      0.10      0.18       586
#            1       0.80      0.99      0.89      3518
#
#     accuracy                           0.80      4608
#    macro avg       0.79      0.46      0.50      4608
# weighted avg       0.80      0.80      0.75      4608

# %%
feature_names = np.array(vect.get_feature_names())

sorted_tfidf_index = X_train_vectorized.max(0).toarray()[0].argsort()

print('Smallest tfidf:\n{}\n'.format(feature_names[sorted_tfidf_index[:10]]))
print('Largest tfidf: \n{}'.format(feature_names[sorted_tfidf_index[:-11:-1]]))
# Out:
# Smallest tfidf:
# ['worry' 'soc' 'bezel' 'asphalt' '960fp' '2x' 'conclusion' 'models'
#  'drops' 'qualcomm']
#
# Largest tfidf:
# ['supper' 'help' 'great' 'grip' 'grt' 'gud' 'hai' 'handwash' 'happi'
#  'happy']

# %%
neg_text_tf = feature_names[sorted_tfidf_index[:100]]
pos_text_tf = feature_names[sorted_tfidf_index[-100:-1]]

# %%
wordcloud = WordCloud(width = 1000, height = 500).generate(str(neg_text_tf))

plt.figure(figsize=(20,10))
plt.figure()
plt.title('negative words')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(width = 1000, height = 500).generate(str(pos_text_tf))

plt.figure(figsize=(20,10))
plt.figure()
plt.title('positive words')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from sklearn import svm
model = svm.SVC()
model.fit(X_train_vectorized, y_train)

predictions = model.predict(vect.transform(X_test))

# %%
from sklearn.metrics import confusion_matrix 
predictions = model.predict(vect.transform(X_test))

print('CM: ',confusion_matrix(y_test,predictions))
# Out:
# CM:  [[ 316   33  155]
#  [  11  452  123]
#  [  31   40 3447]]

# %%
from sklearn.metrics import plot_confusion_matrix
cnf_matrix = confusion_matrix(y_test,predictions,labels=[1, 0, -1])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(model,vect.transform(X_test),y_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
# Accuracy = TP + TN / (TP + TN + FP + FN)
# Precision = TP / (TP + FP)
# Recall = TP / (TP + FN)  Also known as sensitivity, or True Positive Rate
# F1 = 2 * Precision * Recall / (Precision + Recall) 
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, predictions)))
print('Micro Precision: {:}'.format(precision_score(y_test, predictions,average='micro')))
print('Macro Precision: {:}'.format(precision_score(y_test, predictions,average='macro')))
print('Micro Recall: {:}'.format(recall_score(y_test, predictions,average='micro')))
print('Macro Recall: {:}'.format(recall_score(y_test, predictions,average='macro')))
print('Micro F1: {:}'.format(f1_score(y_test, predictions,average='micro')))
print('Macro F1: {:}'.format(f1_score(y_test, predictions,average='macro')))
print(classification_report(y_test, predictions))
# Out:
# Accuracy: 0.91
# Micro Precision: 0.9147135416666666
# Macro Precision: 0.8896676909049898
# Micro Recall: 0.9147135416666666
# Macro Recall: 0.7927110878194239
# Micro F1: 0.9147135416666666
# Macro F1: 0.8328918561578713
#               precision    recall  f1-score   support
#
#           -1       0.88      0.63      0.73       504
#            0       0.86      0.77      0.81       586
#            1       0.93      0.98      0.95      3518
#
#     accuracy                           0.91      4608
#    macro avg       0.89      0.79      0.83      4608
# weighted avg       0.91      0.91      0.91      4608

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train_vectorized, y_train)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
from sklearn.metrics import confusion_matrix 
predictions = model.predict(vect.transform(X_test))

print('CM: ',confusion_matrix(y_test,predictions))
# Out:
# CM:  [[ 368   25  111]
#  [  22  535   29]
#  [ 109   59 3350]]

# %%
from sklearn.metrics import plot_confusion_matrix
cnf_matrix = confusion_matrix(y_test,predictions,labels=[1, 0, -1])
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(model,vect.transform(X_test),y_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report
# Accuracy = TP + TN / (TP + TN + FP + FN)
# Precision = TP / (TP + FP)
# Recall = TP / (TP + FN)  Also known as sensitivity, or True Positive Rate
# F1 = 2 * Precision * Recall / (Precision + Recall) 
print('Accuracy: {:.2f}'.format(accuracy_score(y_test, predictions)))
print('Micro Precision: {:}'.format(precision_score(y_test, predictions,average='micro')))
print('Macro Precision: {:}'.format(precision_score(y_test, predictions,average='macro')))
print('Micro Recall: {:}'.format(recall_score(y_test, predictions,average='micro')))
print('Macro Recall: {:}'.format(recall_score(y_test, predictions,average='macro')))
print('Micro F1: {:}'.format(f1_score(y_test, predictions,average='micro')))
print('Macro F1: {:}'.format(f1_score(y_test, predictions,average='macro')))
print(classification_report(y_test, predictions))
# Out:
# Accuracy: 0.92
# Micro Precision: 0.9229600694444444
# Macro Precision: 0.853885863451393
# Micro Recall: 0.9229600694444444
# Macro Recall: 0.8651245358409101
# Micro F1: 0.9229600694444444
# Macro F1: 0.8592718791590643
#               precision    recall  f1-score   support
#
#           -1       0.74      0.73      0.73       504
#            0       0.86      0.91      0.89       586
#            1       0.96      0.95      0.96      3518
#
#     accuracy                           0.92      4608
#    macro avg       0.85      0.87      0.86      4608
# weighted avg       0.92      0.92      0.92      4608

# %%
import pandas as pd
book_test = pd.read_csv("/Users/Karthick/Desktop/Analysis/books/book.csv")
cam_test = pd.read_csv("/Users/Karthick/Desktop/Analysis/camera/nikon.csv")
mob_test = pd.read_csv("/Users/Karthick/Desktop/Analysis/Electronics_mobile/apple.csv")
ent_test = pd.read_csv("/Users/Karthick/Desktop/Analysis/entertainment/echo.csv")
house_test = pd.read_csv("/Users/Karthick/Desktop/Analysis/household/vim.csv")
watch_test = pd.read_csv("/Users/Karthick/Desktop/Analysis/watches/fastrack.csv")
mob2_test = pd.read_csv("/Users/Karthick/Desktop/Analysis/Electronics_mobile/samsung.csv")

# %%
book_test = book_test.drop(["web-scraper-order", "web-scraper-start-url", "author","next","next-href"], axis=1)
cam_test = cam_test.drop(["web-scraper-order", "web-scraper-start-url", "author","next","next-href"], axis=1)
mob_test = mob_test.drop(["web-scraper-order", "web-scraper-start-url", "author","next","next-href"], axis=1)
ent_test = ent_test.drop(["web-scraper-order", "web-scraper-start-url", "author","next","next-href"], axis=1)
house_test = house_test.drop(["web-scraper-order", "web-scraper-start-url", "author","next","next-href"], axis=1)
watch_test = watch_test.drop(["web-scraper-order", "web-scraper-start-url", "author","next","next-href"], axis=1)
mob2_test = mob2_test.drop(["web-scraper-order", "web-scraper-start-url", "author","next","next-href"], axis=1)

# %%
book_test['Reviews']= book_test["title"].astype(str) +" "+ book_test["content"]
cam_test['Reviews']= cam_test["title"].astype(str) +" "+ cam_test["content"]
mob_test['Reviews']= mob_test["title"].astype(str) +" "+ mob_test["content"]
ent_test['Reviews']= ent_test["title"].astype(str) +" "+ ent_test["content"]
house_test['Reviews']= house_test["title"].astype(str) +" "+ house_test["content"]
watch_test['Reviews']= watch_test["title"].astype(str) +" "+ watch_test["content"]
mob2_test['Reviews']= mob2_test["title"].astype(str) +" "+ mob2_test["content"]

# %%
book_test["Category"] = str('books')
cam_test["Category"] = str('camera')
mob_test["Category"] = str('mobile')
ent_test["Category"] = str('entertainment')
house_test["Category"] = str('households')
watch_test["Category"] = str('watches')
mob2_test["Category"] = str('mobile')

# %%
book_test["Product"] = str('The Intelligent Investor')
cam_test["Product"] = str('Nikon D3500')
mob_test["Product"] = str('Apple iPhone 11 Pro Max ')
ent_test["Product"] = str('Echo Input Portable Smart Speaker ')
house_test["Product"] = str('Vim Dishwash Gel')
watch_test["Product"] = str('Fastrack Reflex 2.0 Activity Tracker')
mob2_test["Product"] = str('Samsung Galaxy M31')

# %%
book_test = book_test.drop(["title","content"],axis=1)
cam_test = cam_test.drop(["title","content"],axis=1)
mob_test = mob_test.drop(["title","content"],axis=1)
ent_test = ent_test.drop(["title","content"],axis=1)
house_test = house_test.drop(["title","content"],axis=1)
watch_test = watch_test.drop(["title","content"],axis=1)
mob2_test = mob2_test.drop(["title","content"],axis=1)

# %%
mob2_test.head()
# Out:
#                                  date              rating  \
# 0  Reviewed in India on 23 March 2020  5.0 out of 5 stars
# 1  Reviewed in India on 25 March 2020  5.0 out of 5 stars
# 2  Reviewed in India on 25 March 2020  5.0 out of 5 stars
# 3  Reviewed in India on 13 March 2020  5.0 out of 5 stars
# 4    Reviewed in India on 25 May 2020  2.0 out of 5 stars
#
#                                              Reviews Category  \
# 0  5 star I wanna tell u something  it is the bes...   mobile
# 1  Good to have it. Over all I really like this p...   mobile
# 2  Beast of battery life The phone is an excellen...   mobile
# 3  Awesome phone Product is very good and awesome...   mobile
# 4  Very very bad choice! I am very disappointed w...   mobile
#
#               Product
# 0  Samsung Galaxy M31
# 1  Samsung Galaxy M31
# 2  Samsung Galaxy M31
# 3  Samsung Galaxy M31
# 4  Samsung Galaxy M31

# %%
frames = [book_test,cam_test,mob_test,ent_test,house_test,watch_test,mob2_test]
test = pd.concat(frames)
test.head()
# Out:
#                                     date              rating  \
# 0       Reviewed in India on 13 May 2017  5.0 out of 5 stars
# 1  Reviewed in India on 17 February 2015  5.0 out of 5 stars
# 2       Reviewed in India on 9 June 2018  5.0 out of 5 stars
# 3   Reviewed in India on 31 January 2018  5.0 out of 5 stars
# 4  Reviewed in India on 20 December 2017  5.0 out of 5 stars
#
#                                              Reviews Category  \
# 0  A Warren Buffet recommended must read. A Warre...    books
# 1           worth reading nice product and nice book    books
# 2  Great book to purchase Great book to understan...    books
# 3  Great book on investing.... This is a great bo...    books
# 4       Five Stars Ever invester must read this book    books
#
#                     Product
# 0  The Intelligent Investor
# 1  The Intelligent Investor
# 2  The Intelligent Investor
# 3  The Intelligent Investor
# 4  The Intelligent Investor

# %%
test = test.dropna()

# %%
test.shape
# Out:
# (11489, 5)

# %%
test['Rating'] = test['rating'].str.split(' ')

# %%
test.head()
# Out:
#                                     date              rating  \
# 0       Reviewed in India on 13 May 2017  5.0 out of 5 stars
# 1  Reviewed in India on 17 February 2015  5.0 out of 5 stars
# 2       Reviewed in India on 9 June 2018  5.0 out of 5 stars
# 3   Reviewed in India on 31 January 2018  5.0 out of 5 stars
# 4  Reviewed in India on 20 December 2017  5.0 out of 5 stars
#
#                                              Reviews Category  \
# 0  A Warren Buffet recommended must read. A Warre...    books
# 1           worth reading nice product and nice book    books
# 2  Great book to purchase Great book to understan...    books
# 3  Great book on investing.... This is a great bo...    books
# 4       Five Stars Ever invester must read this book    books
#
#                     Product                    Rating
# 0  The Intelligent Investor  [5.0, out, of, 5, stars]
# 1  The Intelligent Investor  [5.0, out, of, 5, stars]
# 2  The Intelligent Investor  [5.0, out, of, 5, stars]
# ...

# %%
test["Rating_score"] = test["Rating"].str[0]
test.head()
# Out:
#                                     date              rating  \
# 0       Reviewed in India on 13 May 2017  5.0 out of 5 stars
# 1  Reviewed in India on 17 February 2015  5.0 out of 5 stars
# 2       Reviewed in India on 9 June 2018  5.0 out of 5 stars
# 3   Reviewed in India on 31 January 2018  5.0 out of 5 stars
# 4  Reviewed in India on 20 December 2017  5.0 out of 5 stars
#
#                                              Reviews Category  \
# 0  A Warren Buffet recommended must read. A Warre...    books
# 1           worth reading nice product and nice book    books
# 2  Great book to purchase Great book to understan...    books
# 3  Great book on investing.... This is a great bo...    books
# 4       Five Stars Ever invester must read this book    books
#
#                     Product                    Rating Rating_score
# 0  The Intelligent Investor  [5.0, out, of, 5, stars]          5.0
# 1  The Intelligent Investor  [5.0, out, of, 5, stars]          5.0
# ...

# %%
test = test.drop(["rating","Rating"],axis=1)
test.head()
# Out:
#                                     date  \
# 0       Reviewed in India on 13 May 2017
# 1  Reviewed in India on 17 February 2015
# 2       Reviewed in India on 9 June 2018
# 3   Reviewed in India on 31 January 2018
# 4  Reviewed in India on 20 December 2017
#
#                                              Reviews Category  \
# 0  A Warren Buffet recommended must read. A Warre...    books
# 1           worth reading nice product and nice book    books
# 2  Great book to purchase Great book to understan...    books
# 3  Great book on investing.... This is a great bo...    books
# 4       Five Stars Ever invester must read this book    books
#
#                     Product Rating_score
# 0  The Intelligent Investor          5.0
# 1  The Intelligent Investor          5.0
# 2  The Intelligent Investor          5.0
# 3  The Intelligent Investor          5.0
# 4  The Intelligent Investor          5.0

# %%
test['date'] = test['date'].str.split(n=4)
test.head()
# Out:
#                                           date  \
# 0       [Reviewed, in, India, on, 13 May 2017]
# 1  [Reviewed, in, India, on, 17 February 2015]
# 2       [Reviewed, in, India, on, 9 June 2018]
# 3   [Reviewed, in, India, on, 31 January 2018]
# 4  [Reviewed, in, India, on, 20 December 2017]
#
#                                              Reviews Category  \
# 0  A Warren Buffet recommended must read. A Warre...    books
# 1           worth reading nice product and nice book    books
# 2  Great book to purchase Great book to understan...    books
# 3  Great book on investing.... This is a great bo...    books
# 4       Five Stars Ever invester must read this book    books
#
#                     Product Rating_score
# 0  The Intelligent Investor          5.0
# 1  The Intelligent Investor          5.0
# 2  The Intelligent Investor          5.0
# 3  The Intelligent Investor          5.0
# 4  The Intelligent Investor          5.0

# %%
test["Date"] = test["date"].str[4]
test.head()
# Out:
#                                           date  \
# 0       [Reviewed, in, India, on, 13 May 2017]
# 1  [Reviewed, in, India, on, 17 February 2015]
# 2       [Reviewed, in, India, on, 9 June 2018]
# 3   [Reviewed, in, India, on, 31 January 2018]
# 4  [Reviewed, in, India, on, 20 December 2017]
#
#                                              Reviews Category  \
# 0  A Warren Buffet recommended must read. A Warre...    books
# 1           worth reading nice product and nice book    books
# 2  Great book to purchase Great book to understan...    books
# 3  Great book on investing.... This is a great bo...    books
# 4       Five Stars Ever invester must read this book    books
#
#                     Product Rating_score              Date
# 0  The Intelligent Investor          5.0       13 May 2017
# 1  The Intelligent Investor          5.0  17 February 2015
# 2  The Intelligent Investor          5.0       9 June 2018
# 3  The Intelligent Investor          5.0   31 January 2018
# ...

# %%
test = test.drop(["date"],axis=1)
test.head()
# Out:
#                                              Reviews Category  \
# 0  A Warren Buffet recommended must read. A Warre...    books
# 1           worth reading nice product and nice book    books
# 2  Great book to purchase Great book to understan...    books
# 3  Great book on investing.... This is a great bo...    books
# 4       Five Stars Ever invester must read this book    books
#
#                     Product Rating_score              Date
# 0  The Intelligent Investor          5.0       13 May 2017
# 1  The Intelligent Investor          5.0  17 February 2015
# 2  The Intelligent Investor          5.0       9 June 2018
# 3  The Intelligent Investor          5.0   31 January 2018
# 4  The Intelligent Investor          5.0  20 December 2017

# %%
test["year"] = pd.to_datetime(test["Date"]).dt.year
test["month"] = pd.to_datetime(test["Date"]).dt.month
test.head()
# Out:
#                                              Reviews Category  \
# 0  A Warren Buffet recommended must read. A Warre...    books
# 1           worth reading nice product and nice book    books
# 2  Great book to purchase Great book to understan...    books
# 3  Great book on investing.... This is a great bo...    books
# 4       Five Stars Ever invester must read this book    books
#
#                     Product Rating_score              Date  year  month
# 0  The Intelligent Investor          5.0       13 May 2017  2017      5
# 1  The Intelligent Investor          5.0  17 February 2015  2015      2
# 2  The Intelligent Investor          5.0       9 June 2018  2018      6
# 3  The Intelligent Investor          5.0   31 January 2018  2018      1
# 4  The Intelligent Investor          5.0  20 December 2017  2017     12

# %%
test.to_csv("/Users/Karthick/Desktop/Analysis/test.csv", index=True, encoding='utf8')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
x=test['Rating_score'].value_counts()
x=x.sort_index()
plt.figure(figsize=(10,6))
ax= sns.barplot(x.index, x.values, alpha=0.8)
plt.title("Star Rating Distribution")
plt.ylabel('count')
plt.xlabel('Star Ratings')
rects = ax.patches
labels = x.values
for rect, label in zip(rects, labels):
   height = rect.get_height()
   ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center',
va='bottom')
plt.show();

# %%
plt.figure(figsize=(10,6))
x=test['year'].value_counts()
x=x.sort_index()
plt.title("Reviews per year")
plt.ylabel('count')
plt.xlabel('Year')
ax= sns.barplot(x.index, x.values, alpha=0.8)
rects = ax.patches
labels = x.values
for rect, label in zip(rects, labels):
   height = rect.get_height()
   ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center',
va='bottom')

# %%
test["Date"] = pd.to_datetime(test["Date"])
test["date_diff"] = pd.to_datetime("now")-test["Date"]
test.head()
# Out:
#                                              Reviews Category  \
# 0  A Warren Buffet recommended must read. A Warre...    books
# 1           worth reading nice product and nice book    books
# 2  Great book to purchase Great book to understan...    books
# 3  Great book on investing.... This is a great bo...    books
# 4       Five Stars Ever invester must read this book    books
#
#                     Product Rating_score       Date  year  month  \
# 0  The Intelligent Investor          5.0 2017-05-13  2017      5
# 1  The Intelligent Investor          5.0 2015-02-17  2015      2
# 2  The Intelligent Investor          5.0 2018-06-09  2018      6
# 3  The Intelligent Investor          5.0 2018-01-31  2018      1
# 4  The Intelligent Investor          5.0 2017-12-20  2017     12
#
#                   date_diff
# 0 1128 days 09:56:21.073577
# 1 1944 days 09:56:21.073577
# 2  736 days 09:56:21.073577
# 3  865 days 09:56:21.073577
# 4  907 days 09:56:21.073577

# %%
test["Days"]=test["date_diff"].dt.days

# %%
test = test.drop(["date_diff"],axis=1)
test.head()
# Out:
#                                              Reviews Category  \
# 0  A Warren Buffet recommended must read. A Warre...    books
# 1           worth reading nice product and nice book    books
# 2  Great book to purchase Great book to understan...    books
# 3  Great book on investing.... This is a great bo...    books
# 4       Five Stars Ever invester must read this book    books
#
#                     Product Rating_score       Date  year  month  Days
# 0  The Intelligent Investor          5.0 2017-05-13  2017      5  1128
# 1  The Intelligent Investor          5.0 2015-02-17  2015      2  1944
# 2  The Intelligent Investor          5.0 2018-06-09  2018      6   736
# 3  The Intelligent Investor          5.0 2018-01-31  2018      1   865
# 4  The Intelligent Investor          5.0 2017-12-20  2017     12   907

# %%
test['Reviews1'] = test['Reviews'].str.replace(r'\W+',' ')

# %%
test = test.drop(["Reviews"],axis=1)
test.head()
# Out:
#   Category                   Product Rating_score       Date  year  month  \
# 0    books  The Intelligent Investor          5.0 2017-05-13  2017      5
# 1    books  The Intelligent Investor          5.0 2015-02-17  2015      2
# 2    books  The Intelligent Investor          5.0 2018-06-09  2018      6
# 3    books  The Intelligent Investor          5.0 2018-01-31  2018      1
# 4    books  The Intelligent Investor          5.0 2017-12-20  2017     12
#
#    Days                                           Reviews1
# 0  1128  A Warren Buffet recommended must read A Warren...
# 1  1944           worth reading nice product and nice book
# 2   736  Great book to purchase Great book to understan...
# 3   865  Great book on investing This is a great book o...
# 4   907       Five Stars Ever invester must read this book

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import nltk
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer, WordNetLemmatizer, PorterStemmer
from wordcloud import WordCloud, STOPWORDS
from textblob import TextBlob

# %%
test["Reviews1"]= test["Reviews1"].astype(str)
train.dtypes
# Out:
# Reviews                 object
# Category                object
# Rating_score           float64
# Date            datetime64[ns]
# year                   float64
# month                  float64
# pol                    float64
# polarity                 int32
# dtype: object

# %%
import nltk
nltk.download('stopwords')
stop = stopwords.words('english')
test['Reviews1'] = test['Reviews1'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
test.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\karthick\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#   Category                   Product Rating_score       Date  year  month  \
# 0    books  The Intelligent Investor          5.0 2017-05-13  2017      5
# 1    books  The Intelligent Investor          5.0 2015-02-17  2015      2
# 2    books  The Intelligent Investor          5.0 2018-06-09  2018      6
# 3    books  The Intelligent Investor          5.0 2018-01-31  2018      1
# 4    books  The Intelligent Investor          5.0 2017-12-20  2017     12
#
#    Days                                           Reviews1
# 0  1128  A Warren Buffet recommended must read A Warren...
# 1  1944               worth reading nice product nice book
# 2   736  Great book purchase Great book understand mark...
# 3   865  Great book investing This great book investing...
# 4   907            Five Stars Ever invester must read book

# %%
st = PorterStemmer()
test['Reviews1'] = test['Reviews1'].astype(str).apply(lambda x: " ".join([st.stem(word) for word in x.split()]))

# %%
test.head()
# Out:
#   Category                   Product Rating_score       Date  year  month  \
# 0    books  The Intelligent Investor          5.0 2017-05-13  2017      5
# 1    books  The Intelligent Investor          5.0 2015-02-17  2015      2
# 2    books  The Intelligent Investor          5.0 2018-06-09  2018      6
# 3    books  The Intelligent Investor          5.0 2018-01-31  2018      1
# 4    books  The Intelligent Investor          5.0 2017-12-20  2017     12
#
#    Days                                           Reviews1
# 0  1128  A warren buffet recommend must read A warren b...
# 1  1944                  worth read nice product nice book
# 2   736  great book purchas great book understand marke...
# 3   865  great book invest thi great book invest author...
# 4   907               five star ever invest must read book

# %%
def senti(x):
   return TextBlob(x).sentiment
test['pol'] = test['Reviews1'].apply(senti)
test.head()
# Out:
#   Category                   Product Rating_score       Date  year  month  \
# 0    books  The Intelligent Investor          5.0 2017-05-13  2017      5
# 1    books  The Intelligent Investor          5.0 2015-02-17  2015      2
# 2    books  The Intelligent Investor          5.0 2018-06-09  2018      6
# 3    books  The Intelligent Investor          5.0 2018-01-31  2018      1
# 4    books  The Intelligent Investor          5.0 2017-12-20  2017     12
#
#    Days                                           Reviews1  \
# 0  1128  A warren buffet recommend must read A warren b...
# 1  1944                  worth read nice product nice book
# 2   736  great book purchas great book understand marke...
# 3   865  great book invest thi great book invest author...
# 4   907               five star ever invest must read book
#
#                                         pol
# 0                                (0.0, 0.0)
# 1                 (0.5, 0.7000000000000001)
# ...

# %%
test["sub"]=test["pol"].str[1]
test.head()
# Out:
#   Category                   Product Rating_score       Date  year  month  \
# 0    books  The Intelligent Investor          5.0 2017-05-13  2017      5
# 1    books  The Intelligent Investor          5.0 2015-02-17  2015      2
# 2    books  The Intelligent Investor          5.0 2018-06-09  2018      6
# 3    books  The Intelligent Investor          5.0 2018-01-31  2018      1
# 4    books  The Intelligent Investor          5.0 2017-12-20  2017     12
#
#    Days                                           Reviews1  \
# 0  1128  A warren buffet recommend must read A warren b...
# 1  1944                  worth read nice product nice book
# 2   736  great book purchas great book understand marke...
# 3   865  great book invest thi great book invest author...
# 4   907               five star ever invest must read book
#
#                                         pol       sub
# 0                                (0.0, 0.0)  0.000000
# 1                 (0.5, 0.7000000000000001)  0.700000
# ...

# %%
test["count"] = test['Reviews1'].str.split().str.len()
test.head()
# Out:
#   Category                   Product Rating_score       Date  year  month  \
# 0    books  The Intelligent Investor          5.0 2017-05-13  2017      5
# 1    books  The Intelligent Investor          5.0 2015-02-17  2015      2
# 2    books  The Intelligent Investor          5.0 2018-06-09  2018      6
# 3    books  The Intelligent Investor          5.0 2018-01-31  2018      1
# 4    books  The Intelligent Investor          5.0 2017-12-20  2017     12
#
#    Days                                           Reviews1  \
# 0  1128  A warren buffet recommend must read A warren b...
# 1  1944                  worth read nice product nice book
# 2   736  great book purchas great book understand marke...
# 3   865  great book invest thi great book invest author...
# 4   907               five star ever invest must read book
#
#                                         pol       sub  count
# 0                                (0.0, 0.0)  0.000000     21
# ...

# %%
test = test.drop(["pol"],axis=1)
test.head()
# Out:
#   Category                   Product Rating_score       Date  year  month  \
# 0    books  The Intelligent Investor          5.0 2017-05-13  2017      5
# 1    books  The Intelligent Investor          5.0 2015-02-17  2015      2
# 2    books  The Intelligent Investor          5.0 2018-06-09  2018      6
# 3    books  The Intelligent Investor          5.0 2018-01-31  2018      1
# 4    books  The Intelligent Investor          5.0 2017-12-20  2017     12
#
#    Days                                           Reviews1       sub  count
# 0  1128  A warren buffet recommend must read A warren b...  0.000000     21
# 1  1944                  worth read nice product nice book  0.700000      6
# 2   736  great book purchas great book understand marke...  0.708333     10
# 3   865  great book invest thi great book invest author...  0.750000     16
# 4   907               five star ever invest must read book  0.000000      7

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Fit the TfidfVectorizer to the training data specifiying a minimum document frequency of 5
vect_test = TfidfVectorizer(min_df=5).fit(test["Reviews1"])
len(vect.get_feature_names())
# Out:
# 2867

# %%
test_vectorized = vect_test.transform(test["Reviews1"])

# %%
feature_names = np.array(vect_test.get_feature_names())

sorted_tfidf_index = test_vectorized.max(0).toarray()[0].argsort()

print('Smallest tfidf:\n{}\n'.format(feature_names[sorted_tfidf_index[:10]]))
print('Largest tfidf: \n{}'.format(feature_names[sorted_tfidf_index[:-11:-1]]))
# Out:
# Smallest tfidf:
# ['distract' 'deskphon' 'tatoo' 'everyeher' 'perticl' '3840x2160'
#  'microsoft' 'mount' '16mp' 'juic']
#
# Largest tfidf:
# ['awsom' 'hai' 'happi' 'product' 'leak' 'learn' 'exchang' 'excel' 'like'
#  'poor']

# %%
neg_text_test_tf = feature_names[sorted_tfidf_index[:100]]
pos_text_test_tf = feature_names[sorted_tfidf_index[-100:-1]]

# %%
wordcloud = WordCloud(width = 1000, height = 500).generate(str(neg_text_test_tf))
plt.figure(figsize=(20,10))
plt.figure()
plt.title('negative words')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wordcloud = WordCloud(width = 1000, height = 500).generate(str(pos_text_test_tf))
plt.figure(figsize=(20,10))
plt.figure()
plt.title('positive words')
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
from sklearn import svm
model = svm.SVC()
model.fit(X_train_vectorized, y_train)
test["predictions"] = model.predict(vect.transform(test["Reviews1"]))
test.head()
# Out:
#   Category                   Product Rating_score       Date  year  month  \
# 0    books  The Intelligent Investor          5.0 2017-05-13  2017      5
# 1    books  The Intelligent Investor          5.0 2015-02-17  2015      2
# 2    books  The Intelligent Investor          5.0 2018-06-09  2018      6
# 3    books  The Intelligent Investor          5.0 2018-01-31  2018      1
# 4    books  The Intelligent Investor          5.0 2017-12-20  2017     12
#
#    Days                                           Reviews1       sub  count  \
# 0  1128  A warren buffet recommend must read A warren b...  0.000000     21
# 1  1944                  worth read nice product nice book  0.700000      6
# 2   736  great book purchas great book understand marke...  0.708333     10
# 3   865  great book invest thi great book invest author...  0.750000     16
# 4   907               five star ever invest must read book  0.000000      7
#
#    predictions
# 0            0
# 1            1
# ...

# %%
test.head(30)
# Out:
#    Category                   Product Rating_score       Date  year  month  \
# 0     books  The Intelligent Investor          5.0 2017-05-13  2017      5
# 1     books  The Intelligent Investor          5.0 2015-02-17  2015      2
# 2     books  The Intelligent Investor          5.0 2018-06-09  2018      6
# 3     books  The Intelligent Investor          5.0 2018-01-31  2018      1
# 4     books  The Intelligent Investor          5.0 2017-12-20  2017     12
# 5     books  The Intelligent Investor          5.0 2016-06-15  2016      6
# 6     books  The Intelligent Investor          4.0 2016-05-03  2016      5
# 7     books  The Intelligent Investor          5.0 2019-01-06  2019      1
# 8     books  The Intelligent Investor          5.0 2018-05-26  2018      5
# 9     books  The Intelligent Investor          3.0 2019-11-26  2019     11
# 10    books  The Intelligent Investor          4.0 2018-10-04  2018     10
# ...

# %%
test.tail(30)
# Out:
#      Category             Product Rating_score       Date  year  month  Days  \
# 4971   mobile  Samsung Galaxy M31          5.0 2020-03-18  2020      3    88
# 4972   mobile  Samsung Galaxy M31          4.0 2020-03-23  2020      3    83
# 4973   mobile  Samsung Galaxy M31          2.0 2020-05-27  2020      5    18
# 4974   mobile  Samsung Galaxy M31          4.0 2020-03-09  2020      3    97
# 4975   mobile  Samsung Galaxy M31          5.0 2020-03-27  2020      3    79
# 4976   mobile  Samsung Galaxy M31          5.0 2020-03-27  2020      3    79
# 4977   mobile  Samsung Galaxy M31          5.0 2020-05-22  2020      5    23
# 4978   mobile  Samsung Galaxy M31          3.0 2020-03-29  2020      3    77
# 4979   mobile  Samsung Galaxy M31          5.0 2020-05-27  2020      5    18
# 4980   mobile  Samsung Galaxy M31          5.0 2020-03-22  2020      3    84
# 4981   mobile  Samsung Galaxy M31          1.0 2020-03-10  2020      3    96
# ...

# %%
num_bins = 50
plt.figure(figsize=(10,6))
n, bins, patches = plt.hist(test.predictions, num_bins, facecolor='blue', alpha=0.5)
plt.xlabel('Polarity')
plt.ylabel('Count')
plt.title('Histogram of polarity')
plt.show();

# %%
plt.title("Polarity count")
test['predictions'].value_counts().plot(kind='bar')

# %%
plt.figure(figsize=(10,6))
x=test['predictions'].value_counts()
x=x.sort_index()
plt.title("Polarity count")
plt.ylabel('count')
plt.xlabel('Polarity')
ax= sns.barplot(x.index, x.values, alpha=0.8)
rects = ax.patches
labels = x.values
for rect, label in zip(rects, labels):
  height = rect.get_height()
  ax.text(rect.get_x() + rect.get_width()/2, height + 5, label, ha='center',
va='bottom')
plt.show();

# %%
test.head()
# Out:
#   Category                   Product Rating_score       Date  year  month  \
# 0    books  The Intelligent Investor          5.0 2017-05-13  2017      5
# 1    books  The Intelligent Investor          5.0 2015-02-17  2015      2
# 2    books  The Intelligent Investor          5.0 2018-06-09  2018      6
# 3    books  The Intelligent Investor          5.0 2018-01-31  2018      1
# 4    books  The Intelligent Investor          5.0 2017-12-20  2017     12
#
#    Days                                           Reviews1       sub  count  \
# 0  1128  A warren buffet recommend must read A warren b...  0.000000     21
# 1  1944                  worth read nice product nice book  0.700000      6
# 2   736  great book purchas great book understand marke...  0.708333     10
# 3   865  great book invest thi great book invest author...  0.750000     16
# 4   907               five star ever invest must read book  0.000000      7
#
#    predictions
# 0            0
# 1            1
# ...

# %%
test.dtypes
# Out:
# Category                object
# Product                 object
# Rating_score            object
# Date            datetime64[ns]
# year                     int64
# month                    int64
# Days                     int64
# Reviews1                object
# sub                    float64
# count                    int64
# predictions              int32
# dtype: object

# %%
test["Rating_score"]=pd.to_numeric(test["Rating_score"])
test.head()
# Out:
#   Category                   Product  Rating_score       Date  year  month  \
# 0    books  The Intelligent Investor           5.0 2017-05-13  2017      5
# 1    books  The Intelligent Investor           5.0 2015-02-17  2015      2
# 2    books  The Intelligent Investor           5.0 2018-06-09  2018      6
# 3    books  The Intelligent Investor           5.0 2018-01-31  2018      1
# 4    books  The Intelligent Investor           5.0 2017-12-20  2017     12
#
#    Days                                           Reviews1       sub  count  \
# 0  1128  A warren buffet recommend must read A warren b...  0.000000     21
# 1  1944                  worth read nice product nice book  0.700000      6
# 2   736  great book purchas great book understand marke...  0.708333     10
# 3   865  great book invest thi great book invest author...  0.750000     16
# 4   907               five star ever invest must read book  0.000000      7
#
#    predictions
# 0            0
# 1            1
# ...

# %%
test.dtypes
# Out:
# Category                object
# Product                 object
# Rating_score           float64
# Date            datetime64[ns]
# year                     int64
# month                    int64
# Days                     int64
# Reviews1                object
# sub                    float64
# count                    int64
# predictions              int32
# dtype: object

# %%
test["PD_score"]=test["Rating_score"]+test["Days"]+test["sub"]+test["count"]+test["predictions"]
test.head()
# Out:
#   Category                   Product  Rating_score       Date  year  month  \
# 0    books  The Intelligent Investor           5.0 2017-05-13  2017      5
# 1    books  The Intelligent Investor           5.0 2015-02-17  2015      2
# 2    books  The Intelligent Investor           5.0 2018-06-09  2018      6
# 3    books  The Intelligent Investor           5.0 2018-01-31  2018      1
# 4    books  The Intelligent Investor           5.0 2017-12-20  2017     12
#
#    Days                                           Reviews1       sub  count  \
# 0  1128  A warren buffet recommend must read A warren b...  0.000000     21
# 1  1944                  worth read nice product nice book  0.700000      6
# 2   736  great book purchas great book understand marke...  0.708333     10
# 3   865  great book invest thi great book invest author...  0.750000     16
# 4   907               five star ever invest must read book  0.000000      7
#
#    predictions     PD_score
# 0            0  1154.000000
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11489 entries, 0 to 5000
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Category      11489 non-null  object
#  1   Product       11489 non-null  object
#  2   Rating_score  11489 non-null  float64
#  3   Date          11489 non-null  datetime64[ns]
#  4   year          11489 non-null  int64
#  5   month         11489 non-null  int64
#  6   Days          11489 non-null  int64
#  7   Reviews1      11489 non-null  object
#  8   sub           11489 non-null  float64
#  9   count         11489 non-null  int64
#  10  predictions   11489 non-null  int32
#  11  PD_score      11489 non-null  float64
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(4), object(3)
# memory usage: 1.1+ MB

# %%
test.describe()
# Out:
#        Rating_score          year         month          Days           sub  \
# count  11489.000000  11489.000000  11489.000000  11489.000000  11489.000000
# mean       4.049265   2019.229698      5.350422    299.032988      0.491915
# std        1.412924      1.101832      3.184349    363.709974      0.253989
# min        1.000000   2013.000000      1.000000     16.000000      0.000000
# 25%        4.000000   2019.000000      3.000000     85.000000      0.377778
# 50%        5.000000   2020.000000      4.000000    133.000000      0.537500
# 75%        5.000000   2020.000000      8.000000    389.000000      0.600000
# max        5.000000   2020.000000     12.000000   2528.000000      1.000000
#
#               count   predictions      PD_score
# count  11489.000000  11489.000000  11489.000000
# mean      20.604839      0.742014    324.921021
# std       27.484197      0.571440    359.362863
# min        0.000000     -1.000000     25.000000
# ...

# %%
import numpy as np
test['Polarity'] = np.where(test['predictions'] == 1, 'Pos','Neu')
test['Polarity'] = np.where(test['predictions'] == -1,'Neg',test['Polarity'])
test.head(10)
# Out:
#   Category                   Product  Rating_score       Date  year  month  \
# 0    books  The Intelligent Investor           5.0 2017-05-13  2017      5
# 1    books  The Intelligent Investor           5.0 2015-02-17  2015      2
# 2    books  The Intelligent Investor           5.0 2018-06-09  2018      6
# 3    books  The Intelligent Investor           5.0 2018-01-31  2018      1
# 4    books  The Intelligent Investor           5.0 2017-12-20  2017     12
# 5    books  The Intelligent Investor           5.0 2016-06-15  2016      6
# 6    books  The Intelligent Investor           4.0 2016-05-03  2016      5
# 7    books  The Intelligent Investor           5.0 2019-01-06  2019      1
# 8    books  The Intelligent Investor           5.0 2018-05-26  2018      5
# 9    books  The Intelligent Investor           3.0 2019-11-26  2019     11
#
#    Days                                           Reviews1       sub  count  \
# ...

# %%
plt.figure(figsize=(20,10))
sns.catplot(x="Category", y="PD_score", hue="Polarity", kind="box", data=test);

# %%
plt.figure(figsize=(20,10))
sns.catplot(x="Category", y="PD_score", kind="box", data=test);

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="Category", hue="Polarity", data=test)
for p in ax.patches:
        ax.annotate('{:}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+50))

# %%
plt.figure(figsize=(20,10))
sns.catplot(x="Polarity", hue="Product", col="Category",
                data=test, kind="count",
                height=4, aspect=.5);

# %%
plt.plot(test['year'].value_counts().sort_index())

# %%
plt.figure(figsize=(10,8))
test.Product.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of Products")
# Out:
# Text(0.5, 1.0, 'Test data - % of Products')

# %%
plt.figure(figsize=(10,8))
test.Category.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of category")
# Out:
# Text(0.5, 1.0, 'Test data - % of category')

# %%
plt.figure(figsize=(10,8))
test.Polarity.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of Polarity")
# Out:
# Text(0.5, 1.0, 'Test data - % of Polarity')

# %%
import statsmodels.api as sm
df=test.copy()
df= df.fillna(method='ffill')
X = df[["Days","sub","PD_score","count","predictions"]]
y = df["Rating_score"]
model = sm.OLS(y, X).fit()
predictions = model.predict(X)
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:           Rating_score   R-squared (uncentered):                   1.000
# Model:                            OLS   Adj. R-squared (uncentered):              1.000
# Method:                 Least Squares   F-statistic:                          2.987e+30
# Date:                Sun, 14 Jun 2020   Prob (F-statistic):                        0.00
# Time:                        15:27:33   Log-Likelihood:                      3.2561e+05
# No. Observations:               11489   AIC:                                 -6.512e+05
# Df Residuals:                   11484   BIC:                                 -6.512e+05
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# ...

# %%
test.to_csv("/Users/Karthick/Desktop/Analysis/test_labeled.csv", index=True, encoding='utf8')

# %%
test.dtypes
# Out:
# Category                object
# Product                 object
# Rating_score           float64
# Date            datetime64[ns]
# year                     int64
# month                    int64
# Days                     int64
# Reviews1                object
# sub                    float64
# count                    int64
# predictions              int32
# PD_score               float64
# Polarity                object
# dtype: object

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
test.month.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of months")
# Out:
# Text(0.5, 1.0, 'Test data - % of months')

# %%
plt.plot(test['month'].value_counts().sort_index())

# %%
test.head()
# Out:
#   Category                   Product  Rating_score       Date  year  month  \
# 0    books  The Intelligent Investor           5.0 2017-05-13  2017      5
# 1    books  The Intelligent Investor           5.0 2015-02-17  2015      2
# 2    books  The Intelligent Investor           5.0 2018-06-09  2018      6
# 3    books  The Intelligent Investor           5.0 2018-01-31  2018      1
# 4    books  The Intelligent Investor           5.0 2017-12-20  2017     12
#
#    Days                                           Reviews1       sub  count  \
# 0  1128  A warren buffet recommend must read A warren b...  0.000000     21
# 1  1944                  worth read nice product nice book  0.700000      6
# 2   736  great book purchas great book understand marke...  0.708333     10
# 3   865  great book invest thi great book invest author...  0.750000     16
# 4   907               five star ever invest must read book  0.000000      7
#
#    predictions     PD_score Polarity
# ...

# %%
new = test[['Date', 'Polarity','year','month']].copy()
new.head()
# Out:
#         Date Polarity  year  month
# 0 2017-05-13      Neu  2017      5
# 1 2015-02-17      Pos  2015      2
# 2 2018-06-09      Pos  2018      6
# 3 2018-01-31      Pos  2018      1
# 4 2017-12-20      Neu  2017     12

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="year", hue="Polarity", data= new)
for p in ax.patches:
        ax.annotate('{:}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+50))

# %%
plt.scatter(new['year'],new['month'])

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="month", hue="Polarity", data= new)
for p in ax.patches:
        ax.annotate('{:}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+50))

# %%
new.to_csv("/Users/Karthick/Desktop/Analysis/date.csv", index=True, encoding='utf8')

# %%
y2020 = pd.read_csv("/Users/karthick/Desktop/A2/2020.csv")
y2019 = pd.read_csv("/Users/karthick/Desktop/A2/2019.csv")
y2018 = pd.read_csv("/Users/karthick/Desktop/A2/2018.csv")
y2017 = pd.read_csv("/Users/karthick/Desktop/A2/2017.csv")
y2016 = pd.read_csv("/Users/karthick/Desktop/A2/2016.csv")
y2015 = pd.read_csv("/Users/karthick/Desktop/A2/2015.csv")
y2014 = pd.read_csv("/Users/karthick/Desktop/A2/2014.csv")
y2013 = pd.read_csv("/Users/karthick/Desktop/A2/2013.csv")

# %%
y2020.head()
# Out:
#         Date Polarity  year  month
# 0  1/20/2020      Pos  2020      1
# 1   2/8/2020      Neg  2020      2
# 2  2/20/2020      Pos  2020      2
# 3   3/4/2020      Neu  2020      3
# 4  5/22/2020      Pos  2020      5

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
y2020.month.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of year 2020 - months")
# Out:
# Text(0.5, 1.0, 'Test data - % of year 2020 - months')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
y2020.Polarity.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of year 2020 - Polarity")
# Out:
# Text(0.5, 1.0, 'Test data - % of year 2020 - Polarity')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
y2019.month.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of year 2019 - months")
# Out:
# Text(0.5, 1.0, 'Test data - % of year 2019 - months')

# %%
plt.figure(figsize=(10,8))
y2019.Polarity.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of year 2019 - Polarity")
# Out:
# Text(0.5, 1.0, 'Test data - % of year 2019 - Polarity')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
y2018.month.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of year 2018 - months")
# Out:
# Text(0.5, 1.0, 'Test data - % of year 2018 - months')

# %%
plt.figure(figsize=(10,8))
y2018.Polarity.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of year 2018 - Polarity")
# Out:
# Text(0.5, 1.0, 'Test data - % of year 2018 - Polarity')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
y2017.month.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of year 2017 - months")
# Out:
# Text(0.5, 1.0, 'Test data - % of year 2017 - months')

# %%
plt.figure(figsize=(10,8))
y2017.Polarity.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of year 2017 - Polarity")
# Out:
# Text(0.5, 1.0, 'Test data - % of year 2017 - Polarity')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
y2016.month.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of year 2016 - months")
# Out:
# Text(0.5, 1.0, 'Test data - % of year 2016 - months')

# %%
plt.figure(figsize=(10,8))
y2016.Polarity.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of year 2016 - Polarity")
# Out:
# Text(0.5, 1.0, 'Test data - % of year 2016 - Polarity')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
y2015.month.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of year 2015 - months")
# Out:
# Text(0.5, 1.0, 'Test data - % of year 2015 - months')

# %%
plt.figure(figsize=(10,8))
y2015.Polarity.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of year 2015 - Polarity")
# Out:
# Text(0.5, 1.0, 'Test data - % of year 2015 - Polarity')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
y2014.month.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of year 2014 - months")
# Out:
# Text(0.5, 1.0, 'Test data - % of year 2014 - months')

# %%
plt.figure(figsize=(10,8))
y2014.Polarity.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of year 2014 - Polarity")
# Out:
# Text(0.5, 1.0, 'Test data - % of year 2014 - Polarity')

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
y2013.month.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of year 2013 - months")
# Out:
# Text(0.5, 1.0, 'Test data - % of year 2013 - months')

# %%
plt.figure(figsize=(10,8))
y2013.Polarity.value_counts().plot(kind='pie', autopct='%1.0f%%')
plt.title("Test data - % of year 2013 - Polarity")
# Out:
# Text(0.5, 1.0, 'Test data - % of year 2013 - Polarity')

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="month", hue="Polarity", data= y2020)
for p in ax.patches:
        ax.annotate('{:}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+50))

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="month", hue="Polarity", data= y2019)
for p in ax.patches:
        ax.annotate('{:}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+5))

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="month", hue="Polarity", data= y2018)
for p in ax.patches:
        ax.annotate('{:}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+1))

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="month", hue="Polarity", data= y2017)
for p in ax.patches:
        ax.annotate('{:}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+0.5))

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="month", hue="Polarity", data= y2016)
for p in ax.patches:
        ax.annotate('{:}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+0.25))

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="month", hue="Polarity", data= y2015)
for p in ax.patches:
        ax.annotate('{:}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+0.25))

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="month", hue="Polarity", data= y2014)
for p in ax.patches:
        ax.annotate('{:}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+0.25))

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="month", hue="Polarity", data= y2013)
for p in ax.patches:
        ax.annotate('{:}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.05))

# %%
plt.figure(figsize=(20,10))
ax = sns.countplot(x="Product", hue="Polarity", data=test)
for p in ax.patches:
        ax.annotate('{:}'.format(p.get_height()), (p.get_x()+0.05, p.get_height()+50))
